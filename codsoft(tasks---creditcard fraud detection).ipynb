# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Load the datasets, handling potential errors
train_df = pd.read_csv('/content/fraudTrain.csv', on_bad_lines='skip', engine="python")
test_df = pd.read_csv('/content/fraudTest.csv', on_bad_lines='skip', engine="python")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-6089afb5789d> in <cell line: 0>()
#      16 # Train a Logistic Regression model
#      17 model = LogisticRegression()
# ---> 18 model.fit(X_train, y_train)
#      19
#      20 # Make predictions on the test set
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1220             _dtype = [np.float64, np.float32]
#    1221
# -> 1222         X, y = validate_data(
#    1223             self,
#    1224             X,
#
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import LabelEncoder

# Load the datasets, handling potential errors
train_df = pd.read_csv('/content/fraudTrain.csv', on_bad_lines='skip', engine="python")
test_df = pd.read_csv('/content/fraudTest.csv', on_bad_lines='skip', engine="python")

# Convert 'trans_date_trans_time' to datetime objects
train_df['trans_date_trans_time'] = pd.to_datetime(train_df['trans_date_trans_time'])
test_df['trans_date_trans_time'] = pd.to_datetime(test_df['trans_date_trans_time'])

# Extract features from 'trans_date_trans_time'
train_df['transaction_hour'] = train_df['trans_date_trans_time'].dt.hour
test_df['transaction_hour'] = test_df['trans_date_trans_time'].dt.hour

# Optionally, you can extract other features like day of week, month, etc.
# train_df['transaction_dayofweek'] = train_df['trans_date_trans_time'].dt.dayofweek
# test_df['transaction_dayofweek'] = test_df['trans_date_trans_time'].dt.dayofweek


# Assuming 'isFraud' is the target variable column
X_train = train_df.drop(['is_fraud', 'trans_date_trans_time'], axis=1)  # Drop the original 'trans_date_trans_time' column
y_train = train_df['is_fraud']
X_test = test_df.drop(['is_fraud', 'trans_date_trans_time'], axis=1)  # Drop the original 'trans_date_trans_time' column
y_test = test_df['is_fraud']


# Create a LabelEncoder object
encoder = LabelEncoder()

# Iterate over each column in X_train
for col in X_train.columns:
    # Check if the column contains string values
    if X_train[col].dtype == 'object':
        # Fit the encoder on the combined training and testing data for this column
        combined_data = pd.concat([X_train[col], X_test[col]], ignore_index=True)
        encoder.fit(combined_data)

        # Transform both training and testing data
        X_train[col] = encoder.transform(X_train[col])
        X_test[col] = encoder.transform(X_test[col])

# Train a Logistic Regression model
model = LogisticRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.9961401355721147
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
